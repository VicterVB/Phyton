# %% [markdown]
# ### <center> ![logo_nieuw.jpg](data:image/jpeg;base64,...)
#
# ## <center> **Opgaven Programming Fundamentals**
# ### <center> **Prof. Bachelor ELO-ICT - Academiejaar 2023 - 2024**
# ### <center> ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # <center> Les 1: Intro

# %% [markdown]
# ### Richtlijnen
# Vooraleer te starten met het programmeren in Python moet je eerst je ontwikkelomgeving goed instellen. De volgende stappen zal je moeten doornemen:
# - [Installeer de Python interpreter](https://www.python.org/downloads/)
# - [Installeer de IDE VS Code](https://code.visualstudio.com/)
# - [Installeer extensies in VS Code om Python te kunnen gebruiken in VS Code](https://marketplace.visualstudio.com/items?itemName=ms-python.python)
# - [Installeer extensies in VS Code om Jupyter Notebooks te activeren in VS Code](https://code.visualstudio.com/docs/datascience/jupyter-notebooks)
#
#
# In de eerste oefeningensessies zullen we korte programmeeroefeningen opgeven. Deze kan je rechtstreeks aanvullen in de notebook zelf.
#
# Maak een folder op je systeem, waaronder je al je Python oefeningen kan bewaren. Maak deze folder je workspace in VS Code.

# %% [markdown]
# ### Oefening 1
# Print volgende tekst naar het scherm:
#
# > Academiejaar 2023-2024:
#
# > Welkom ELO-ICT!

# %%
print('Academiejaar 2023-2024:')
print('Welkom ELO-ICT!')
# Out:
# Academiejaar 2023-2024:
# Welkom ELO-ICT!

# %% [markdown]
# ### Oefening 2
# Creëer een variabele genaamd `greeting` met de waarde 'Hola Mundo!' en print de waarde van deze variabele.

# %%
greeting = 'Hola Mundo!'
print(greeting)
# Out:
# Hola Mundo!

# %% [markdown]
# ### Oefening 3
#
# Welke van de onderstaande variabelenamen zijn toegelaten in Python? Bij variabelenamen die niet
# geldig zijn, geef de reden(en).
# - xyz
# - Variabele
# - 2good2go
# - een_zeer_lange_variabele_naam
# - _nog_een_zeer_lange_variabele_naam
# - toBeContinued
# - #ELO/ICT
#
# Controleer je antwoord door elk van de variabelen aan te maken en er een waarde aan toe te kennen.

# %%
XYZ = 1 #hoofdletters 
Variabele = 2 # hoofdletter in het begin
#2good2go = 3 #Er staat een getal aan het begin van de variabele. 
een_zeer_lange_variabele_naam = 4
_nog_een_zeer_lange_variabele_neem = 5 
toBeContinued = 6 #hoofdletters 
#ELO/ICT = 7 #Er wordt een command line van gemaakt door de #

# %% [markdown]
# ### Oefening 4
# Los onderstaande oefeningen op, stop het resultaat in een variabele en print uit.
#  - Bereken de som van 15 en 23.
#  - Concateneer de volgende twee strings: 'Programming' en ' Fundamentals'.
#  - Bereken: $4^{12}$
#  - Bereken de rest wanneer je 17 deelt door 5
#  - Maak een variabele om je voornaam in te bewaren, maak teven een variabele voor je achternaam. Plak beide aan elkaar.

# %%
som = 15 +23
print('het resultaat is', som)
# Out:
# het resultaat is 38

# %%
string1 = 'Programming'
string2 = ' Fundamentals'
string1_en_2 = string1 + string2
print(string1_en_2)
# Out:
# Programming Fundamentals

# %%
twaalfde_macht_wortel = 4 ** 12
print('het resultaat is', twaalfde_macht_wortel)
# Out:
# het resultaat is 16777216

# %%
rest = 17 % 5
print('de rest is',rest)
# Out:
# de rest is 2

# %%
voornaam = 'Victer'
achternaam = ' Van Bogaert'
voledige_naam = voornaam + achternaam
print(voledige_naam)
# Out:
# Victer Van Bogaert

# %% [markdown]
# ### Oefening 5
# Schrijf een programma dat het volgende op het scherm doet verschijnen:
# ````
# ---------------------------------------
# WARNING
# Possible virus detected
# Reboot and run virus remover software
# ---------------------------------------
# ````

# %%
print('---------------------------------------')
print('WARNING')
print('POssible vius detected')
print('Reboot and run viras remover software')
print('---------------------------------------')
# Out:
# ---------------------------------------
# WARNING
# POssible vius detected
# Reboot and run viras remover software
# ---------------------------------------

# %% [markdown]
# ### Oefening 6
#
# Schrijf een programma dat het volgende op het scherm drukt:

# %% [markdown]
# ````
# *
# **
# ***
# ****
# ````

# %%
print('*')
print('**')
print('***')
print('****')

sterretje = '*'
print(sterretje)
print(sterretje * 2)
print(sterretje * 3)
print(sterretje * 4)
# Out:
# *
# **
# ***
# ****
# *
# **
# ***
# ****

# %% [markdown]
# ### Oefening 7
# Schrijf een programma dat een datum kan afprinten in volgende vorm :
# dag - maand - jaar.
#
# Gebruik hierbij 3 variabelen om respectievelijkde dag, maand en jaar bij te houden.  Op het scherm verschijnt bijvoorbeeld :
#
# De opgegeven datum is : 01 - 09 - 2023

# %%
dag = 1
maand = 9
jaar = 2023
print(dag, ' - ', maand, ' - ',jaar)
# Out:
# 1  -  9  -  2023

# %% [markdown]
# ### Oefening 8
#
# Ga na wat de gegevenstypes zijn van onderstaande Python objecten. Tijdens de komende lessen gaan we deze in meer detail bespreken.
#
# - 42
# - 42.0
# - 5 + 8j
# - ()
# - []
# - '#'
# - "12345"
# - " "
# - ""
# - (5.332, 'z')
# - ["een","vreemde","zin"]
# - {"Belgium":11144420, "Netherlands":16802463, "Luxembourg": 536761}
# - True
# - False

# %%
print(type(42))
print(type(42.0))
print(type(5 + 8j))
print(type(()))
print(type([]))
print(type('#'))
print(type("13245"))
print(type(" "))
print(type(""))
print(type((5.332, 'z')))
print(type(["een", "vraamde", "zin"]))
print(type({"Belgium":11144420, "Netherlands":16802463, "Luxembourg": 536761}))
print(type(True))
print(type(False))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'tuple'>
# <class 'list'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'tuple'>
# <class 'list'>
# <class 'dict'>
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# ### Oefening 9
#
# Maak 2 variabelen aan:
# - ken aan beide een willekeurig geheel getal toe. Pas alle rekenkundige operaties op ze toe en print telkens het resultaat naar het scherm.
# - ken aan beide een willekeurig reëel getal toe.  Pas alle rekenkundige operaties op ze toe en print telkens het resultaat naar het scherm.

# %%
getal1 = 4
getal2 = 9
plus = getal1 + getal2 
min = getal1 - getal2
maal = getal1 * getal2
delen = getal2 / getal2
gehele_deling = getal1 // getal2
rest = getal1 % getal2
macht = getal1 ** getal2

print(plus)
print(min)
print(maal)
print(delen)
print(gehele_deling)
print(rest)
print(macht)
# Out:
# 13
# -5
# 36
# 1.0
# 0
# 4
# 262144

# %%
getal1 = 4.9
getal2 = 9.8
plus = getal1 + getal2 
min = getal1 - getal2
maal = getal1 * getal2
delen = getal2 / getal2
gehele_deling = getal1 // getal2
rest = getal1 % getal2
macht = getal1 ** getal2

print(plus)
print(min)
print(maal)
print(delen)
print(gehele_deling)
print(rest)
print(macht)
# Out:
# 14.700000000000001
# -4.9
# 48.02000000000001
# 1.0
# 0.0
# 4.9
# 5806595.648211227

# %% [markdown]
# ### Oefening 10
#
# Bedenk zelf een programma met een syntax error en een programma met een runtime error. Geef telkens aan waar de fout zit.

# %%
print("ddfd) #geen einde van de string
# Out:
#   Cell In[30], line 1
#     print("ddfd)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print(hello) #geen variabele hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\victe\OneDrive - ODISEE\1ICT5\Programming Fundamentals\Phyton\Les1_Intro_Oef.ipynb Cell 30 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/victe/OneDrive%20-%20ODISEE/1ICT5/Programming%20Fundamentals/Phyton/Les1_Intro_Oef.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> print(hello)
#
# NameError: name 'hello' is not defined

# %% [markdown]
# ### Oefening 11
#
# Corrigeer de syntax en runtime fouten in volgende oefening.
#
# ```
# prin("Welkom bij de Python les")
# def som_functie(a, b)
#     return a + b
# resultaat = som_functie(5, "10")
# print("Het resultaat is: ", resultaat
# ```

# %%
print("Welkom bij de Python les")
def som_functie(a, b):
    return a + b
resultaat = som_functie(5, 10)
print("Het resultaat is: ", resultaat)
# Out:
# Welkom bij de Python les
# Het resultaat is:  15

# %% [markdown]
# ### Oefening 12
# Bekijk de volgende instructies en tracht te verklaren waarom een foutmelding optreedt.
#
# ```
# x = 2
# print ( x + 5)
# print ( y = x + 5)

# %%
x = 2
print ( x + 5)
print ( y = x + 5) #er wordt een resultaat uitgerekent in de print
# Out:
# 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\victe\OneDrive - ODISEE\1ICT5\Programming Fundamentals\Phyton\Les1_Intro_Oef.ipynb Cell 34 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/victe/OneDrive%20-%20ODISEE/1ICT5/Programming%20Fundamentals/Phyton/Les1_Intro_Oef.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> x = 2
#       <a href='vscode-notebook-cell:/c%3A/Users/victe/OneDrive%20-%20ODISEE/1ICT5/Programming%20Fundamentals/Phyton/Les1_Intro_Oef.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a> print ( x + 5)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/victe/OneDrive%20-%20ODISEE/1ICT5/Programming%20Fundamentals/Phyton/Les1_Intro_Oef.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a> print ( y = x + 5) #er wordt een resultaat uitgerekent in de print
#
# TypeError: 'y' is an invalid keyword argument for print()

# %% [markdown]
# ### Oefening 13
#
# Print een tabel die minstens 20 keywords bevat. Je tabel bevat
# 4 kolommen ( en dus minstens 5 rijen).

# %%
print('and\tad\tassert\tbreak\tclass')
print('def\tdel\telif\telse\texcept')
print('for\tfor\tglobal\tif\timport')
print('is\tlambda\tin\tnot\tor')
# Out:
# and	ad	assert	break	class
# def	del	elif	else	except
# for	for	global	if	import
# is	lambda	in	not	or

# %% [markdown]
# ### Oefening 14
#
# Voer de volgende instructies uit:
#
# ```
# dier = "hond"
# voorwerp = "stoel"
# getal = 12
# dier = voorwerp
# voorwerp = getal
# getal = dier
#
# ```
#
# - Wat zijn de uiteindelijke waarden van de variabelen dier, voorwerp en getal?
# - Kan je elke waarde nog terugvinden?

# %%
dier = "hond"
voorwerp = "stoel"
getal = 12
dier = voorwerp
voorwerp = getal
getal = dier

print('de variabele dier wordt:', dier)
print('de variabele voorwerp wordt:', voorwerp)
print('de variabele getal wordt:',getal)
# Out:
# de variabele dier wordt: stoel
# de variabele voorwerp wordt: 12
# de variabele getal wordt: stoel

# %% [markdown]
# ### Oefening 15
#
# Schrijf een programma dat 3 variabelen met respektievelijke namen _var1_, _var2_ en _var3_ aanmaakt en er 3 verschillende float waarden aan toekent. Je programma moet deze nu cyclisch permuteren, m.a.w. var1  krijgt de waarde van var2, var2 de waarde van var3 en var3 de waarde van var1. Merk op de waarden moeten effectief van geheugenlocatie worden gewisseld! De printout instructies voor en na de permutatie zijn exact dezelfde.
# Voorbeeld output van je programma :
#
# ```
# Variabele var1 is: 1.4
# Variabele var2 is: 1.5
# Variabele var3 is: 1.6
# Na permutatie
# Variabele var1 is: 1.5
# Variabele var2 is: 1.6
# Variabele var3 is: 1.4
# ```

# %%
var1 = 2.4
var2 = 2.5
var3 = 2.6
temp = var1
print('Variabele var1 is:', var1)
print('Variabele var2 is:', var2)
print('Variabele var3 is:', var3)

var1 = var2
var2 = var3
var3 = temp

print("Na permutatie")
print('Variabele var1 is:', var1)
print('Variabele var2 is:', var2)
print('Variabele var3 is:', var3)
# Out:
# Variabele var1 is: 2.4
# Variabele var2 is: 2.5
# Variabele var3 is: 2.6
# Na permutatie
# Variabele var1 is: 2.5
# Variabele var2 is: 2.6
# Variabele var3 is: 2.4

# %% [markdown]
# ### Oefening 16
# Op aarde hebben mensen dezelfde massa als op de maan, maar hun gewicht is anders. Schrijf een programma, waarin je zowel je gewicht op de aarde als op de maan berekent. Print beide uit.
#
# Neem je massa op aarde en stop deze in een variabele (een weegschaal op aarde meet eigenlijk je gewicht op aarde maar rekent dit dan om naar een massa).
#
# Hou rekening met de valversnelling op:
# - de aarde $= 9.81 \frac{m}{s^2}$
# - de maan $= 1.62 \frac{m}{s^2}$.
#
# Maak voor deze beide waarden constanten aan in je programma.
#
# Een gewicht druk je uit in Newton, een massa in kg.

# %%
VALVERSNELLING_AARDE = 9.81
GVALVERSNELLING_MAAN = 1.62

gewicht =  81 

massa_aarde = gewicht * VALVERSNELLING_AARDE
massa_maan = gewicht * GVALVERSNELLING_MAAN

print('Mijn gewicht op de aarde is:', massa_aarde, 'newton.')
print('Mijn gewicht op de maan is:', massa_maan, 'newton.')
# Out:
# Mijn gewicht op de aarde is: 794.61 newton.
# Mijn gewicht op de maan is: 131.22 newton.
